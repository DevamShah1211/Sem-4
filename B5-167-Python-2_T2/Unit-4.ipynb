# %%
import pandas as pd
import numpy as np
data={"Name":["Rohit","Dhoni","Virat","Sakshi","Anushka"],
      "Age":[45,60,20,50,19],
      "Gender":["Male","Male","Male","Female","Female"]
     }
x=pd.DataFrame(data)
# x
x["Category"]=np.where(x["Age"]>=60,"Elder",np.where(x["Age"]<=20,"Teenager","Middle"))
x
# Out:
#       Name  Age  Gender  Category
# 0    Rohit   45    Male    Middle
# 1    Dhoni   60    Male     Elder
# 2    Virat   20    Male  Teenager
# 3   Sakshi   50  Female    Middle
# 4  Anushka   19  Female  Teenager

# %%
x=pd.read_csv("marksheet of sem 4 python.. - Copy.csv")
x=pd.DataFrame(x)
x
b5=(x["Batch/Div"]=="B5").shape[0]
b5
# Out:
# 980

# %%
b5=x[(x["Batch/Div"]=="B5")&(x["marks"]==25.0)]
b5
# Out:
#     RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 30   1.0       SY-2    CEA     158.0    2.300220e+13        B5
# 68  50.0       SY-2    CSE     150.0    2.300220e+13        B5
# 70  50.0       SY-2    CSE     172.0    2.300220e+13        B5
# 72  50.0       SY-2    CSE     176.0    2.300220e+13        B5
# 75  50.0       SY-2    CSE     151.0    2.300220e+13        B5
# 77  50.0       SY-2    CSE     145.0    2.300220e+13        B5
# 80  50.0       SY-2    CSE     177.0    2.400220e+13        B5
# 82  50.0       SY-2    CSE     169.0    2.400220e+13        B5
# 83  50.0       SY-2    CEA     168.0    2.300220e+13        B5
#
#                     STUDENT NAME MENTOR SHORT NAME  marks
# 30       DHAKATE HARDIKA KRISHNA               VHA   25.0
# 68  PRAJAPATI RACHIT YOGESHKUMAR               PDO   25.0
# 70           SAURABH KUMAR YADAV               PSP   25.0
# 72        SHELADIYA OM VIPULBHAI               NAS   25.0
# ...

# %%
b5=x[(x["MENTOR SHORT NAME"]=="DVP")&(x["marks"]<9)]
b5
# Out:
# Empty DataFrame
# Columns: [RANK, DEPARTMENT, BRANCH, ROLL NO., ENROLLMENT NO., Batch/Div, STUDENT NAME, MENTOR SHORT NAME, marks]
# Index: []

# %%
avg=x[(x["Batch/Div"]=="B5")]["marks"].mean()
avg
# Out:
# 22.03125

# %%
avg=x[(x["Batch/Div"]=="B7")]["marks"].mean()
avg
# Out:
# 19.05263157894737

# %%
marks=x[(x["DEPARTMENT"]=="SY-2")&(x["marks"]==25.0)].shape[0]
marks
# Out:
# 45

# %%
avg=x[(x["Batch/Div"]=="A7")]["marks"].mean()
avg
# Out:
# 16.375

# %%
x["Grade"]=np.where(x["marks"]>23,"A+",np.where(x["marks"]>21,"A",np.where(x["marks"]>19,"B",np.where(x["marks"]>15,"C","D"))))
x
# Out:
#        RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 0       1.0       SY-1     CE      80.0    2.300220e+13        A3
# 1       1.0       SY-1     CE       6.0    2.300220e+13        A1
# 2       1.0       SY-1     CE       9.0    2.300220e+13        A1
# 3       1.0       SY-1     CE       2.0    2.300220e+13        A1
# 4       1.0       SY-1     CE      35.0    2.300220e+13        A1
# ..      ...        ...    ...       ...             ...       ...
# 975  1053.0       SY-4    CST     249.0    2.300220e+13        D7
# 976  1054.0       SY-4    CST     247.0    2.300220e+13        D7
# 977  1055.0       SY-4    CST     244.0    2.300220e+13        D7
# 978  1056.0       SY-4    CST     248.0    2.300220e+13        D7
# 979  1057.0       SY-4  CS&IT     232.0    2.300220e+13        D7
#
#                      STUDENT NAME MENTOR SHORT NAME  marks Grade
# 0      BAMBHROLIYA HIT NARESHBHAI               UMS   25.0    A+
# ...

# %%
first=x[(x["Grade"]=="A+")&(x["Batch/Div"]=="B5")]
first
# Out:
#       RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 30     1.0       SY-2    CEA     158.0    2.300220e+13        B5
# 68    50.0       SY-2    CSE     150.0    2.300220e+13        B5
# 70    50.0       SY-2    CSE     172.0    2.300220e+13        B5
# 72    50.0       SY-2    CSE     176.0    2.300220e+13        B5
# 75    50.0       SY-2    CSE     151.0    2.300220e+13        B5
# 77    50.0       SY-2    CSE     145.0    2.300220e+13        B5
# 80    50.0       SY-2    CSE     177.0    2.400220e+13        B5
# 82    50.0       SY-2    CSE     169.0    2.400220e+13        B5
# 83    50.0       SY-2    CEA     168.0    2.300220e+13        B5
# 132  100.0       SY-2    CSE     164.0    2.300220e+13        B5
# 180  159.0       SY-2    CSE     153.0    2.300220e+13        B5
# 191  159.0       SY-2    CSE     166.0    2.300220e+13        B5
# 195  159.0       SY-2    CEA     163.0    2.300220e+13        B5
#
# ...

# %%
second=x[(x["Grade"]=="A")&(x["Batch/Div"]=="B5")]
second
# Out:
#       RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 242  221.0       SY-2    CSE     155.0    2.300220e+13        B5
# 244  221.0       SY-2    CSE     165.0    2.300220e+13        B5
# 245  221.0       SY-2    CSE     152.0    2.300220e+13        B5
# 304  280.0       SY-2    CSE     149.0    2.300220e+13        B5
# 343  328.0       SY-2    CSE     161.0    2.300220e+13        B5
# 347  328.0       SY-2    CSE     159.0    2.300220e+13        B5
# 394  378.0       SY-2    CSE     173.0    2.300220e+13        B5
# 400  378.0       SY-2    CEA     170.0    2.300220e+13        B5
#
#                           STUDENT NAME MENTOR SHORT NAME  marks Grade
# 242    PATEL DARSHANKUMAR JITENDRABHAI               VBY   23.0     A
# 244             PATEL KRISH ASHOKKUMAR               DDP   23.0     A
# 245             PATIL DHRUVIT PRASHANT               PSP   23.0     A
# 304         VEKARIYA VANSH RAKESHKUMAR               DPS   23.0     A
# ...

# %%
third=x[(x["Grade"]=="B")&(x["Batch/Div"]=="B5")]
third
# Out:
#       RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 446  476.0       SY-2    CEA     148.0    2.300220e+13        B5
# 487  476.0       SY-2    CEA     148.0    2.300220e+13        B5
#
#      STUDENT NAME MENTOR SHORT NAME  marks Grade
# 446  ADITI MAURYA               TAT   21.0     B
# 487  ADITI MAURYA               TAT   21.0     B

# %%
fourth=x[(x["Grade"]=="C")&(x["Batch/Div"]=="B5")]
fourth
# Out:
#       RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 517  590.0       SY-2    CSE     175.0    2.300220e+13        B5
# 519  590.0       SY-2    CSE     154.0    2.300220e+13        B5
# 522  590.0       SY-2    CSE     157.0    2.300220e+13        B5
# 570  648.0       SY-2    CSE     174.0    2.300220e+13        B5
# 577  648.0       SY-2    CSE     167.0    2.400220e+13        B5
# 578  648.0       SY-2    CEA     171.0    2.300220e+13        B5
# 599  681.0       SY-2    CSE     156.0    2.300220e+13        B5
# 600  681.0       SY-2    CSE     160.0    2.300220e+13        B5
#
#                         STUDENT NAME MENTOR SHORT NAME  marks Grade
# 517        HIRPARA PRINSI CHETANBHAI               VBY   19.0     C
# 519           PARIKH HENIT SAMIRBHAI               PBZ   19.0     C
# 522          SHAH YASHVI BHANUPRASAD               PDO   19.0     C
# 570  KHANIYA NAITIKKUMAR HARSHADBHAI               MSS   18.0     C
# ...

# %%
fifth=x[(x["Grade"]=="D")&(x["Batch/Div"]=="B5")]
fifth
# Out:
#        RANK DEPARTMENT BRANCH  ROLL NO.  ENROLLMENT NO. Batch/Div  \
# 733   807.0       SY-2    CSE     147.0    2.300220e+13        B5
# 970  1048.0       SY-2    CSE     146.0    2.300220e+13        B5
#
#                       STUDENT NAME MENTOR SHORT NAME  marks Grade
# 733      KHANPARA DHRUV DINESHBHAI               MSS   15.0     D
# 970  PARAKHIYA DISHANT BHAVESHBHAI               VBY    NaN     D

# %%
x[x["Batch/Div"]=="B5"]["Grade"].unique()
# Out:
# array(['A+', 'A', 'B', 'C', 'D'], dtype=object)

# %%
x[x["Batch/Div"]=="B5"]["Grade"].value_counts()
# Out:
# A+    13
# C      8
# A      8
# D      2
# B      2
# Name: Grade, dtype: int64

# %%
# You've been given a dataset with apartment area and price information. There's a noticeable non-linear relationship between
# area and price. To address this you intend to categorize them into 'High', 'Medium', and 'Low' groups. Prices above $3,000,000
# are 'High', below $2,000,000 are 'Low', and between $2,000,000 and $3,000,000 are 'Medium'. Write a code to achieve this
# assuming that dataset has two columns named area and price.
import pandas as pd
import numpy as np
data={
    "Area":["Paldi","Paldi","Mahalaxmi","Dharnidhar","Anjli"],
    "Price":[3000000,2000000,4000000,1000000,2500000]
}
x=pd.DataFrame(data)
# x
x["Cat"]=np.where(x["Price"]>3000000,"High",np.where(x["Price"]<2000000,"Low","Medium"))
x
# Out:
#          Area    Price     Cat
# 0       Paldi  3000000  Medium
# 1       Paldi  2000000  Medium
# 2   Mahalaxmi  4000000    High
# 3  Dharnidhar  1000000     Low
# 4       Anjli  2500000  Medium

# %%
# In a survey dataset, you have a column representing participants' ages. You want to categorize ages into 'Young', 'Middle-aged',
# and 'Elderly' groups. Ages below 30 are 'Young', ages between 30 and 60 are 'Middle-aged', and ages above 60 are 'Elderly'.
# Write a code to achieve this assuming the dataset has a column named 'age'.
import pandas as pd
import numpy as np
data={"Name":["Rohit","Dhoni","Virat","Sakshi","Anushka"],
      "Age":[45,60,20,50,19],
      "Gender":["Male","Male","Male","Female","Female"]
     }
x=pd.DataFrame(data)
# x
x["Category"]=np.where(x["Age"]>60,"Elder",np.where(x["Age"]<30,"Young","Middle"))
x
# Out:
#       Name  Age  Gender Category
# 0    Rohit   45    Male   Middle
# 1    Dhoni   60    Male   Middle
# 2    Virat   20    Male    Young
# 3   Sakshi   50  Female   Middle
# 4  Anushka   19  Female    Young

# %%
# In a customer dataset, you have a column representing customer incomes. You want to categorize incomes into 'Low', 'Medium',
# and 'High' groups. Incomes below 30000 are 'Low', incomes between 30000 and 70000 are 'Medium', and incomes above 70000
# are 'High'. Write a code to achieve this assuming the dataset has a column named 'income'.
data={
    "Income":[100000,70000,20000,40000,50000,75000]
}
x=pd.DataFrame(data)
x
x["cat"]=np.where(x["Income"]<30000,"Low",np.where(x["Income"]>70000,"High","Medium"))
x
# Out:
#    Income     cat
# 0  100000    High
# 1   70000  Medium
# 2   20000     Low
# 3   40000  Medium
# 4   50000  Medium
# 5   75000    High

# %%
x=pd.read_csv("marksheet of sem 4 python.. - Copy.csv")
x=pd.DataFrame(x)
y=x[x["ENROLLMENT NO."]==24002171220018]
y
# Out:
# Empty DataFrame
# Columns: [RANK, DEPARTMENT, BRANCH, ROLL NO., ENROLLMENT NO., Batch/Div, STUDENT NAME, MENTOR SHORT NAME, marks]
# Index: []
